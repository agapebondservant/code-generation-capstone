# %%
##############################################################################
# Handle imports
##############################################################################
import traceback
from huggingface_hub import snapshot_download, login, HfApi
from sklearn.model_selection import train_test_split
from transformers import AutoModelForCausalLM, AutoTokenizer
from dotenv import load_dotenv
load_dotenv()
import torch
import optuna
import traceback
from peft import PeftModel
torch.cuda.empty_cache()

# %%
# #############################
# # Manually upload DORA model
# #############################
checkpoint_path="./models/dora/ibm-granite_granite-4.0-h-tiny/experiment/checkpoint-1248"
model_id="ibm-granite/granite-4.0-h-tiny"
new_model_id="oaawofolu/granite-4.0-h-tiny_d"

model = AutoModelForCausalLM.from_pretrained(model_id, 
                                             
                                             trust_remote_code=True,
                                             
                                             device_map="cuda")

model = PeftModel.from_pretrained(model, checkpoint_path)

model = model.merge_and_unload()

tokenizer = AutoTokenizer.from_pretrained(model_id, local_files_only=True)
    
if tokenizer.pad_token is None:
    
    tokenizer.pad_token = tokenizer.eos_token

tokenizer.padding_side = 'right'

model.push_to_hub(new_model_id)

tokenizer.push_to_hub(new_model_id)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# No files have been modified since last commit. Skipping to prevent empty commit.
# CommitInfo(commit_url='https://huggingface.co/oaawofolu/granite-4.0-h-tiny_d/commit/f1e62c2d53fbb58e4d99d4cd6161460ff952b7c1', commit_message='Upload tokenizer', commit_description='', oid='f1e62c2d53fbb58e4d99d4cd6161460ff952b7c1', pr_url=None, repo_url=RepoUrl('https://huggingface.co/oaawofolu/granite-4.0-h-tiny_d', endpoint='https://huggingface.co', repo_type='model', repo_id='oaawofolu/granite-4.0-h-tiny_d'), pr_revision=None, pr_num=None)

# %%
#############################
# Manually upload LoRA model
#############################
# checkpoint_path="./models/lora/ibm-granite_granite-4.0-h-tiny/experiment/checkpoint-1248"
# model_id="ibm-granite/granite-4.0-h-tiny"
# new_model_id="oaawofolu/granite-4.0-h-tiny_l"

# model = AutoModelForCausalLM.from_pretrained(model_id, 
                                             
#                                              trust_remote_code=True,
                                             
#                                              device_map="cuda")

# model = PeftModel.from_pretrained(model, checkpoint_path)

# model = model.merge_and_unload()

# tokenizer = AutoTokenizer.from_pretrained(model_id, local_files_only=True)
    
# if tokenizer.pad_token is None:
    
#     tokenizer.pad_token = tokenizer.eos_token

# tokenizer.padding_side = 'right'

# model.push_to_hub(new_model_id)

# tokenizer.push_to_hub(new_model_id)
# Out:
# The fast path is not available because on of `(selective_state_update, causal_conv1d_fn, causal_conv1d_update)` is None. Falling back to the naive implementation. To install follow https://github.com/state-spaces/mamba/#installation and https://github.com/Dao-AILab/causal-conv1d
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# No files have been modified since last commit. Skipping to prevent empty commit.
# CommitInfo(commit_url='https://huggingface.co/oaawofolu/granite-4.0-h-tiny_l/commit/617b9c68f301a36f630123b1b9e06f57d5b81981', commit_message='Upload tokenizer', commit_description='', oid='617b9c68f301a36f630123b1b9e06f57d5b81981', pr_url=None, repo_url=RepoUrl('https://huggingface.co/oaawofolu/granite-4.0-h-tiny_l', endpoint='https://huggingface.co', repo_type='model', repo_id='oaawofolu/granite-4.0-h-tiny_l'), pr_revision=None, pr_num=None)
